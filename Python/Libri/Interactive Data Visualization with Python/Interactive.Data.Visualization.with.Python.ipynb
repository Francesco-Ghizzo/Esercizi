# %%
import pandas as pd
import numpy as np
import bokeh
import plotly

# %%
url_co2 = 'https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/co2.csv'
co2 = pd.read_csv(url_co2)
co2
# Out:
#          country  1800  1801  1802  1803  ...   2010   2011   2012   2013   2014
# 0    Afghanistan   NaN   NaN   NaN   NaN  ...  0.294  0.412  0.350  0.316  0.299
# 1        Albania   NaN   NaN   NaN   NaN  ...  1.560  1.790  1.680  1.730  1.960
# 2        Algeria   NaN   NaN   NaN   NaN  ...  3.300  3.290  3.460  3.510  3.720
# 3        Andorra   NaN   NaN   NaN   NaN  ...  6.120  5.870  5.920  5.900  5.830
# 4         Angola   NaN   NaN   NaN   NaN  ...  1.240  1.250  1.330  1.250  1.290
# ..           ...   ...   ...   ...   ...  ...    ...    ...    ...    ...    ...
# 187    Venezuela   NaN   NaN   NaN   NaN  ...  6.510  6.000  6.650  6.070  6.030
# 188      Vietnam   NaN   NaN   NaN   NaN  ...  1.610  1.700  1.570  1.610  1.800
# 189        Yemen   NaN   NaN   NaN   NaN  ...  0.993  0.811  0.749  0.997  0.865
# 190       Zambia   NaN   NaN   NaN   NaN  ...  0.194  0.206  0.249  0.261  0.288
# 191     Zimbabwe   NaN   NaN   NaN   NaN  ...  0.552  0.665  0.530  0.776  0.780
#
# [192 rows x 216 columns]

# %%
url_gm = 'https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/gapminder.csv'
gm = pd.read_csv(url_gm)
gm
# Out:
#            Country  Year  ...     gdp                 region
# 0      Afghanistan  1964  ...  1182.0             South Asia
# 1      Afghanistan  1965  ...  1182.0             South Asia
# 2      Afghanistan  1966  ...  1168.0             South Asia
# 3      Afghanistan  1967  ...  1173.0             South Asia
# 4      Afghanistan  1968  ...  1187.0             South Asia
# ...            ...   ...  ...     ...                    ...
# 10106        Åland  2002  ...     NaN  Europe & Central Asia
# 10107        Åland  2003  ...     NaN  Europe & Central Asia
# 10108        Åland  2004  ...     NaN  Europe & Central Asia
# 10109        Åland  2005  ...     NaN  Europe & Central Asia
# 10110        Åland  2006  ...     NaN  Europe & Central Asia
#
# [10111 rows x 8 columns]

# %%
gm = gm.drop_duplicates()
gm
# Out:
#            Country  Year  ...     gdp                 region
# 0      Afghanistan  1964  ...  1182.0             South Asia
# 1      Afghanistan  1965  ...  1182.0             South Asia
# 2      Afghanistan  1966  ...  1168.0             South Asia
# 3      Afghanistan  1967  ...  1173.0             South Asia
# 4      Afghanistan  1968  ...  1187.0             South Asia
# ...            ...   ...  ...     ...                    ...
# 10106        Åland  2002  ...     NaN  Europe & Central Asia
# 10107        Åland  2003  ...     NaN  Europe & Central Asia
# 10108        Åland  2004  ...     NaN  Europe & Central Asia
# 10109        Åland  2005  ...     NaN  Europe & Central Asia
# 10110        Åland  2006  ...     NaN  Europe & Central Asia
#
# [10111 rows x 8 columns]

# %%
df_gm = gm[['Country','region']]
df_gm
# Out:
#            Country                 region
# 0      Afghanistan             South Asia
# 1      Afghanistan             South Asia
# 2      Afghanistan             South Asia
# 3      Afghanistan             South Asia
# 4      Afghanistan             South Asia
# ...            ...                    ...
# 10106        Åland  Europe & Central Asia
# 10107        Åland  Europe & Central Asia
# 10108        Åland  Europe & Central Asia
# 10109        Åland  Europe & Central Asia
# 10110        Åland  Europe & Central Asia
#
# [10111 rows x 2 columns]

# %%
df_w_regions = pd.merge(co2, df_gm, left_on='country', right_on='Country', how='inner')
df_w_regions = df_w_regions.drop_duplicates()
df_w_regions
# Out:
#                   country  ...                      region
# 0             Afghanistan  ...                  South Asia
# 50                Albania  ...       Europe & Central Asia
# 100               Algeria  ...  Middle East & North Africa
# 150                Angola  ...          Sub-Saharan Africa
# 200   Antigua and Barbuda  ...                     America
# ...                   ...  ...                         ...
# 8400              Vanuatu  ...         East Asia & Pacific
# 8450            Venezuela  ...                     America
# 8500              Vietnam  ...         East Asia & Pacific
# 8550               Zambia  ...          Sub-Saharan Africa
# 8600             Zimbabwe  ...          Sub-Saharan Africa
#
# [173 rows x 218 columns]

# %%
df_w_regions = df_w_regions.drop('Country', axis='columns')
df_w_regions
# Out:
#                   country  1800  1801  ...   2013   2014                      region
# 0             Afghanistan   NaN   NaN  ...  0.316  0.299                  South Asia
# 50                Albania   NaN   NaN  ...  1.730  1.960       Europe & Central Asia
# 100               Algeria   NaN   NaN  ...  3.510  3.720  Middle East & North Africa
# 150                Angola   NaN   NaN  ...  1.250  1.290          Sub-Saharan Africa
# 200   Antigua and Barbuda   NaN   NaN  ...  5.360  5.380                     America
# ...                   ...   ...   ...  ...    ...    ...                         ...
# 8400              Vanuatu   NaN   NaN  ...  0.420  0.595         East Asia & Pacific
# 8450            Venezuela   NaN   NaN  ...  6.070  6.030                     America
# 8500              Vietnam   NaN   NaN  ...  1.610  1.800         East Asia & Pacific
# 8550               Zambia   NaN   NaN  ...  0.261  0.288          Sub-Saharan Africa
# 8600             Zimbabwe   NaN   NaN  ...  0.776  0.780          Sub-Saharan Africa
#
# [173 rows x 217 columns]

# %%
new_co2 = pd.melt(df_w_regions, id_vars=['country', 'region'])
new_co2
# Out:
#                    country                      region variable  value
# 0              Afghanistan                  South Asia     1800    NaN
# 1                  Albania       Europe & Central Asia     1800    NaN
# 2                  Algeria  Middle East & North Africa     1800    NaN
# 3                   Angola          Sub-Saharan Africa     1800    NaN
# 4      Antigua and Barbuda                     America     1800    NaN
# ...                    ...                         ...      ...    ...
# 37190              Vanuatu         East Asia & Pacific     2014  0.595
# 37191            Venezuela                     America     2014  6.030
# 37192              Vietnam         East Asia & Pacific     2014  1.800
# 37193               Zambia          Sub-Saharan Africa     2014  0.288
# 37194             Zimbabwe          Sub-Saharan Africa     2014  0.780
#
# [37195 rows x 4 columns]

# %%
columns = ['country', 'region', 'year', 'CO2']
new_co2.columns = columns
new_co2
# Out:
#                    country                      region  year    CO2
# 0              Afghanistan                  South Asia  1800    NaN
# 1                  Albania       Europe & Central Asia  1800    NaN
# 2                  Algeria  Middle East & North Africa  1800    NaN
# 3                   Angola          Sub-Saharan Africa  1800    NaN
# 4      Antigua and Barbuda                     America  1800    NaN
# ...                    ...                         ...   ...    ...
# 37190              Vanuatu         East Asia & Pacific  2014  0.595
# 37191            Venezuela                     America  2014  6.030
# 37192              Vietnam         East Asia & Pacific  2014  1.800
# 37193               Zambia          Sub-Saharan Africa  2014  0.288
# 37194             Zimbabwe          Sub-Saharan Africa  2014  0.780
#
# [37195 rows x 4 columns]

# %%
df_co2 = new_co2[new_co2['year'].astype('int64')>1963]
df_co2
# Out:
#                    country                      region  year     CO2
# 28372          Afghanistan                  South Asia  1964  0.0863
# 28373              Albania       Europe & Central Asia  1964  1.0900
# 28374              Algeria  Middle East & North Africa  1964  0.4600
# 28375               Angola          Sub-Saharan Africa  1964  0.2010
# 28376  Antigua and Barbuda                     America  1964  1.5400
# ...                    ...                         ...   ...     ...
# 37190              Vanuatu         East Asia & Pacific  2014  0.5950
# 37191            Venezuela                     America  2014  6.0300
# 37192              Vietnam         East Asia & Pacific  2014  1.8000
# 37193               Zambia          Sub-Saharan Africa  2014  0.2880
# 37194             Zimbabwe          Sub-Saharan Africa  2014  0.7800
#
# [8823 rows x 4 columns]

# %%
df_co2 = df_co2.sort_values(by=['country','year'])
df_co2
# Out:
#            country              region  year     CO2
# 28372  Afghanistan          South Asia  1964  0.0863
# 28545  Afghanistan          South Asia  1965  0.1010
# 28718  Afghanistan          South Asia  1966  0.1080
# 28891  Afghanistan          South Asia  1967  0.1240
# 29064  Afghanistan          South Asia  1968  0.1160
# ...            ...                 ...   ...     ...
# 36502     Zimbabwe  Sub-Saharan Africa  2010  0.5520
# 36675     Zimbabwe  Sub-Saharan Africa  2011  0.6650
# 36848     Zimbabwe  Sub-Saharan Africa  2012  0.5300
# 37021     Zimbabwe  Sub-Saharan Africa  2013  0.7760
# 37194     Zimbabwe  Sub-Saharan Africa  2014  0.7800
#
# [8823 rows x 4 columns]
